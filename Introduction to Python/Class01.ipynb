# %%
# 1. comment

# %%
# 2. import statement
import math # import the built-in module 'math' which has the sqrt function, log, and exponential

# %%
math.sqrt(9)  #this is how we use square root function(sqrt)
# Out:
# 3.0

# %%
# 3. multiline comment/shortcut of commenting

# hello everyone
# this is a multi-line comment
# multi-line comment (''')

# %%
# 4. Variable Declarations
# ----------------------------
# Variables are containers for storing data values
number1= 25           #integer variable
number2= 9.5          #float variable
message= "Welcome!!"  #String variable

# %%
print(number1)
print(number2)
print(message)
# Out:
# 25
# 9.5
# Welcome!!

# %%
#Using the import statement of math
sqrt_value = math.sqrt(number1)

# %%
#printing 
print("Squart root of ",number1,"is: ", sqrt_value)
# Out:
# Squart root of  25 is:  5.0

# %%
#Quiz question and solution
# Ques: consider there is a function name randint(n1,n2) to generate any one random number between n1 and n2 range and 
#       for that one has to use library name  random, Task is to write two line of code how to use it as we did in math.sqrt()

#Answer:
import random
random.randint(0,10)
# Out:
# 9

# %% [markdown]
# Multiple things in a PRINT Statement:

# %%
sum_result = number1 + number2

# %%
print("The sum of ",number1 ," and ", number2,"is: ", sum_result)
# Out:
# The sum of  25  and  9.5 is:  34.5

# %% [markdown]
# Tokens, Keywords, and Identifiers

# %%
#Tokens are small units in Python, like constants, variables, operators, etc.

# %%
import keyword
print("Python keywords are: ", keyword.kwlist)   #this displays all the keywords in python
# Out:
# Python keywords are:  ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Variables and Identifiers are the same. 
# Identifiers are case sensitive.

# %% [markdown]
# QUIZ Time
#
# Mention reason for invalid identifier in following list
#
# 1. 2var: this is invalid because starts with a number
# 2. my-name: special character except '_' is not allowed
# 3. class: this is a python keyword
# 4. first name: spaces are not allowed
# 5. price$: no special character other than '_' is allowed

# %% [markdown]
# Variables and Data Types:

# %%
sale_count= 500         #int
discount= 200.50        #float
product_name= "Laptop"  #String
is_available= True      #Boolean

# %%
#checking the type of variable

print(type(sale_count))
print(type(discount))
print(type(product_name))
print(type(is_available))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
